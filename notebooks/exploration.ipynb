# %%
import pandas as pd
import matplotlib.pyplot as plt

data_path = "../data/processed/cleaned_products.csv"
df= pd.read_csv(data_path)


print("Basic Statistics")
print(df.describe())

plt.hist(df["price"], bins=20, edgecolor="black")

plt.title("Distribución de precios")
plt.xlabel("Precio")
plt.ylabel("Frecuencia")
plt.show()

print("Productos más caros:")
highestPrices = df.nlargest(5,"price")
print(highestPrices)
# Out:
# Basic Statistics
#              price
# count     3.000000
# mean    773.266667
# std     350.449313
# min     410.660000
# 25%     604.830000
# 50%     799.000000
# 75%     954.570000
# max    1110.140000
# Productos más caros:
#                title                                        description  \
# 0   Dell Latitude...  Dell Latitude 5480, 14" FHD, Core i5-7300U, 8G...
# 1  Asus ROG STRIX...  Asus ROG STRIX GL553VD-DM256, 15.6" FHD, Core ...
# 2   Asus VivoBook...  Asus VivoBook 15 X540NA-GQ026T Chocolate Black...
#
#      price
# 0  1110.14
# 1   799.00
# 2   410.66
